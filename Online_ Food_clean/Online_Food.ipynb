# %%
import pandas as pd

# %%
data = pd.read_csv("onlinefoods.csv")

# %%
data .head(2)
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
#
#   Output  Feedback Unnamed: 12
# 0    Yes  Positive         Yes
# 1    Yes  Positive         Yes

# %%
type(data["latitude"][1])
# Out:
# np.float64(12.977)

# %%
data.shape
# Out:
# (388, 13)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         388 non-null    int64
#  1   Gender                      388 non-null    str
#  2   Marital Status              388 non-null    str
#  3   Occupation                  388 non-null    str
#  4   Monthly Income              388 non-null    str
#  5   Educational Qualifications  388 non-null    str
#  6   Family size                 388 non-null    int64
#  7   latitude                    388 non-null    float64
#  8   longitude                   388 non-null    float64
#  9   Pin code                    388 non-null    int64
#  10  Output                      388 non-null    str
#  11  Feedback                    388 non-null    str
#  12  Unnamed: 12                 388 non-null    str
# dtypes: float64(2), int64(3), str(8)
# ...

# %%
"""
Deleting redundant columns.
Renaming the columns.
Dropping duplicates.
Remove the NaN values from the dataset
Check for some more Transformations
"""

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'latitude', 'longitude',
#        'Pin code', 'Output', 'Feedback', 'Unnamed: 12'],
#       dtype='str')

# %%
data_to_keep = ['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
                'Educational Qualifications', 'Family size']
data_to_drop = ['latitude', 'longitude',
                'Pin code', 'Unnamed: 12']

# %%
try:
  print(len(data_to_keep))
except NameError:
  data_to_keep = ['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
          'Educational Qualifications', 'Family size']
  print(len(data_to_keep))
# Out:
# 7

# %%
try:
  print(len(data_to_drop))
except NameError:
  data_to_drop = ['latitude', 'longitude', 'Pin code', 'Unnamed: 12']
  print(len(data_to_drop))
# Out:
# 4

# %%
data
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %% [markdown]
# # filttering columns the we wnated

# %%
data = pd.read_csv("onlinefoods.csv")
data["Age"]
# Out:
# 0      20
# 1      24
# 2      22
# 3      22
# 4      22
#        ..
# 383    23
# 384    23
# 385    22
# 386    23
# 387    23
# Name: Age, Length: 388, dtype: int64

# %%
data[data_to_keep]
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size
# 0                Post Graduate            4
# 1                     Graduate            3
# 2                Post Graduate            3
# 3                     Graduate            6
# ...

# %%
modified_data = data[data_to_keep]

# %%
modified_data
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size
# 0                Post Graduate            4
# 1                     Graduate            3
# 2                Post Graduate            3
# 3                     Graduate            6
# ...

# %% [markdown]
# # 2nd way ,droping the unccessaty

# %%
data.drop(columns=[col for col in data_to_drop if col in data.columns], inplace=True)

# %%
data
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size
# 0                Post Graduate            4
# 1                     Graduate            3
# 2                Post Graduate            3
# 3                     Graduate            6
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size'],
#       dtype='str')

# %% [markdown]
# # reaniming columns

# %%
data.rename(columns={"Monthly Income ": "Monthly salary"}, inplace=True)

# %%
data
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size
# 0                Post Graduate            4
# 1                     Graduate            3
# 2                Post Graduate            3
# 3                     Graduate            6
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(159)

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.isna().sum()
# Out:
# Age                           0
# Gender                        0
# Marital Status                0
# Occupation                    0
# Monthly Income                0
# Educational Qualifications    0
# Family size                   0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# Age                           0
# Gender                        0
# Marital Status                0
# Occupation                    0
# Monthly Income                0
# Educational Qualifications    0
# Family size                   0
# dtype: int64

# %%
data
# Out:
#      Age  Gender Marital Status      Occupation   Monthly Income  \
# 0     20  Female         Single         Student        No Income
# 1     24  Female         Single         Student   Below Rs.10000
# 2     22    Male         Single         Student   Below Rs.10000
# 3     22  Female         Single         Student        No Income
# 4     22    Male         Single         Student   Below Rs.10000
# ..   ...     ...            ...             ...              ...
# 299   25  Female         Single        Employee  More than 50000
# 321   21    Male        Married        Employee  More than 50000
# 342   22    Male        Married  Self Employeed   10001 to 25000
# 363   31    Male        Married        Employee  More than 50000
# 369   30    Male        Married        Employee  More than 50000
#
#     Educational Qualifications  Family size
# 0                Post Graduate            4
# 1                     Graduate            3
# 2                Post Graduate            3
# ...

# %%
data[ "Age {Months}"] =data ["Age"]*12

# %%
data["Gender"].apply (lambda x :"F" if x == " Female" else "M")
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 299    M
# 321    M
# 342    M
# 363    M
# 369    M
# Name: Gender, Length: 229, dtype: str

# %%
data
# Out:
#      Age  Gender Marital Status      Occupation   Monthly Income  \
# 0     20  Female         Single         Student        No Income
# 1     24  Female         Single         Student   Below Rs.10000
# 2     22    Male         Single         Student   Below Rs.10000
# 3     22  Female         Single         Student        No Income
# 4     22    Male         Single         Student   Below Rs.10000
# ..   ...     ...            ...             ...              ...
# 299   25  Female         Single        Employee  More than 50000
# 321   21    Male        Married        Employee  More than 50000
# 342   22    Male        Married  Self Employeed   10001 to 25000
# 363   31    Male        Married        Employee  More than 50000
# 369   30    Male        Married        Employee  More than 50000
#
#     Educational Qualifications  Family size  Age {Months}
# 0                Post Graduate            4           240
# 1                     Graduate            3           288
# ...

# %%
data.head(2)
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  Age {Months}
# 0              Post Graduate            4           240
# 1                   Graduate            3           288

# %%
data ["Family size"] = data ["Family size"].apply(lambda x : "large" if x > 3 else " small ")

# %%
data
# Out:
#      Age  Gender Marital Status      Occupation   Monthly Income  \
# 0     20  Female         Single         Student        No Income
# 1     24  Female         Single         Student   Below Rs.10000
# 2     22    Male         Single         Student   Below Rs.10000
# 3     22  Female         Single         Student        No Income
# 4     22    Male         Single         Student   Below Rs.10000
# ..   ...     ...            ...             ...              ...
# 299   25  Female         Single        Employee  More than 50000
# 321   21    Male        Married        Employee  More than 50000
# 342   22    Male        Married  Self Employeed   10001 to 25000
# 363   31    Male        Married        Employee  More than 50000
# 369   30    Male        Married        Employee  More than 50000
#
#     Educational Qualifications Family size  Age {Months}
# 0                Post Graduate       large           240
# 1                     Graduate      small            288
# ...

# %%
# First, check if 'Output' column exists
if 'Output' in data.columns:
  data["Output"] = data["Output"].apply(lambda x: 1 if str(x).strip().lower() == "yes" else 0)
else:
  print("'Output' column not found. Available columns are:")
  print(data.columns.tolist())
# Out:
# 'Output' column not found. Available columns are:
# ['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income', 'Educational Qualifications', 'Family size', 'Age {Months}']

# %%
if 'Output' in data.columns:
  data['Output'] = data['Output'].astype(float)
else:
  print("'Output' column not found. Available columns are:")
  print(data.columns.tolist())
# Out:
# 'Output' column not found. Available columns are:
# ['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income', 'Educational Qualifications', 'Family size', 'Age {Months}']

# %%
data
# Out:
#      Age  Gender Marital Status      Occupation   Monthly Income  \
# 0     20  Female         Single         Student        No Income
# 1     24  Female         Single         Student   Below Rs.10000
# 2     22    Male         Single         Student   Below Rs.10000
# 3     22  Female         Single         Student        No Income
# 4     22    Male         Single         Student   Below Rs.10000
# ..   ...     ...            ...             ...              ...
# 299   25  Female         Single        Employee  More than 50000
# 321   21    Male        Married        Employee  More than 50000
# 342   22    Male        Married  Self Employeed   10001 to 25000
# 363   31    Male        Married        Employee  More than 50000
# 369   30    Male        Married        Employee  More than 50000
#
#     Educational Qualifications Family size  Age {Months}
# 0                Post Graduate       large           240
# 1                     Graduate      small            288
# ...

# %%
data .to_excel("Online_Food_cleaned.xlsx", index=False)

# %%
data. to_csv("Online_Food_cleaned.csv", index=False)

# %%
data = data.reset_index(drop=True)

# %%
data
# Out:
#      Age  Gender Marital Status      Occupation   Monthly Income  \
# 0     20  Female         Single         Student        No Income
# 1     24  Female         Single         Student   Below Rs.10000
# 2     22    Male         Single         Student   Below Rs.10000
# 3     22  Female         Single         Student        No Income
# 4     22    Male         Single         Student   Below Rs.10000
# ..   ...     ...            ...             ...              ...
# 224   25  Female         Single        Employee  More than 50000
# 225   21    Male        Married        Employee  More than 50000
# 226   22    Male        Married  Self Employeed   10001 to 25000
# 227   31    Male        Married        Employee  More than 50000
# 228   30    Male        Married        Employee  More than 50000
#
#     Educational Qualifications Family size  Age {Months}
# 0                Post Graduate       large           240
# 1                     Graduate      small            288
# ...
