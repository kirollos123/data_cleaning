# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.3'

# %%
pd.read_csv('netflix1.csv')
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
data = pd.read_csv('netflix1.csv')

# %%
data.head(789)
# Out:
#     show_id     type                             title         director  \
# 0        s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1        s3  TV Show                         Ganglands  Julien Leclercq
# 2        s6  TV Show                     Midnight Mass    Mike Flanagan
# 3       s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4        s8    Movie                           Sankofa     Haile Gerima
# ..      ...      ...                               ...              ...
# 784    s647    Movie   The House of Flowers: The Movie      Manolo Caro
# 785    s655    Movie                           #Selfie   Cristina Jacob
# 786    s656    Movie                        #Selfie 69   Cristina Jacob
# 787    s657    Movie                   Love Is a Story   Cristina Jacob
# 788    s645    Movie                     Good on Paper   Kimmy Gatewood
#
#            country date_added  release_year rating  duration  \
# ...

# %%
data.tail(20)
# Out:
#      show_id     type                      title   director         country  \
# 8770   s8721  TV Show  What Happens to My Family  Not Given          Turkey
# 8771   s8593  TV Show            Timeless Season  Not Given        Pakistan
# 8772   s8722  TV Show              What Is Love?  Not Given          Taiwan
# 8773   s8727  TV Show       When Calls the Heart  Not Given   United States
# 8774   s8737  TV Show              Who's the One  Not Given          Taiwan
# 8775   s8741  TV Show                Wild Alaska  Not Given  United Kingdom
# 8776   s8742  TV Show                Wild Arabia  Not Given  United Kingdom
# 8777   s8748  TV Show                  Winsanity  Not Given   United States
# 8778   s8750  TV Show                 Winter Sun  Not Given          Turkey
# 8779   s8756  TV Show          Women Behind Bars  Not Given   United States
# 8780   s8759  TV Show     World's Busiest Cities  Not Given  United Kingdom
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   str
#  1   type          8790 non-null   str
#  2   title         8790 non-null   str
#  3   director      8790 non-null   str
#  4   country       8790 non-null   str
#  5   date_added    8790 non-null   str
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   str
#  8   duration      8790 non-null   str
#  9   listed_in     8790 non-null   str
# dtypes: int64(1), str(9)
# memory usage: 686.8 KB

# %%
"""Deleting redundant columns.
Renaming the columns.
Dropping duplicates.
Remove the NaN values from the dataset
Check for some more Transformations"""

# %%
data.head(1)
# Out:
#   show_id   type                 title         director        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
#
#   date_added  release_year rating duration      listed_in
# 0  9/25/2021          2020  PG-13   90 min  Documentaries

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='str')

# %%
data [["rating"]]
# Out:
#      rating
# 0     PG-13
# 1     TV-MA
# 2     TV-MA
# 3     TV-PG
# 4     TV-MA
# ...     ...
# 8785  TV-PG
# 8786  TV-Y7
# 8787  TV-PG
# 8788   TV-Y
# 8789  TV-Y7
#
# [8790 rows x 1 columns]

# %%
if 'rating' in data.columns:
  data.drop(columns=['rating'], inplace=True)

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'duration', 'listed_in'],
#       dtype='str')

# %%
example=

# %%
from cmath import pi


new_columns_name=[] 
for i in data.columns :
  new_columns_name.append(i.capitalize())

# %%
data.columns=new_columns_name

# %%
data.head()
# Out:
#   Show_id     Type                             Title         Director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          Country Date_added  Release_year  Duration  \
# 0  United States  9/25/2021          2020    90 min
# 1         France  9/24/2021          2021  1 Season
# 2  United States  9/24/2021          2021  1 Season
# 3         Brazil  9/22/2021          2021    91 min
# 4  United States  9/24/2021          1993   125 min
#
#                                            Listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# ...

# %%
data.coulmns = ['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added', 'release_year', 'rating', 'duration', 'listed_in', 'description']
# Out:
# /tmp/ipykernel_28406/3203558861.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   data.coulmns = ['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added', 'release_year', 'rating', 'duration', 'listed_in', 'description']

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
#for cleaning dupocate 
data.drop_duplicates(inplace=True)

# %%
data.isna
# Out:
# <bound method DataFrame.isna of      Show_id     Type                             Title         Director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             Country  Date_added  Release_year   Duration  \
# ...

# %%
#if we had na values we can use the following code to remove them
data.dropna(inplace=True)

# %%
data.head()
# Out:
#   Show_id     Type                             Title         Director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          Country Date_added  Release_year  Duration  \
# 0  United States  9/25/2021          2020    90 min
# 1         France  9/24/2021          2021  1 Season
# 2  United States  9/24/2021          2021  1 Season
# 3         Brazil  9/22/2021          2021    91 min
# 4  United States  9/24/2021          1993   125 min
#
#                                            Listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# ...

# %%
data['Show_id'].unique()
# Out:
# <StringArray>
# [   's1',    's3',    's6',   's14',    's8',    's9',   's10',  's939',
#    's13',  's940',
#  ...
#  's8759', 's8776', 's8781', 's8785', 's8796', 's8797', 's8798', 's8801',
#  's8784', 's8786']
# Length: 8790, dtype: str

# %%
if isinstance(data, pd.DataFrame):
  data["Show_id"] = data["Show_id"].astype(str).str.split("s").str[1]
else:
  data = data.astype(str).str.split("s").str[1]

# %%
type(data["Show_id	"][0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 type(data["Show_id      "][0])
#
# File ~/data cleaning/venv/lib/python3.12/site-packages/pandas/core/series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File ~/data cleaning/venv/lib/python3.12/site-packages/pandas/core/series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
# ...

# %%
"/" "-"

# %%
col = 'Date_added' if 'Date_added' in data.columns else 'date_added'
data[col] = data[col].astype(str).str.replace("/", "-", regex=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 col = 'Date_added' if 'Date_added' in data.columns else 'date_added'
#       2 data[col] = data[col].astype(str).str.replace("/", "-", regex=False)
#
# File ~/data cleaning/venv/lib/python3.12/site-packages/pandas/core/generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
data.to_csv('netflix_cleaned.csv', index=False)

# %%
data.to_excel('netflix_cleaned.xlsx', index=False)

# %%
data["Show_id"] = data["Show_id"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 data["Show_id"] = data["Show_id"].astype(int)
#
# File ~/data cleaning/venv/lib/python3.12/site-packages/pandas/core/series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File ~/data cleaning/venv/lib/python3.12/site-packages/pandas/core/series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
# ...

# %%
data
# Out:
# 0          1
# 1          3
# 2          6
# 3         14
# 4          8
#         ...
# 8785    8797
# 8786    8798
# 8787    8801
# 8788    8784
# 8789    8786
# Name: Show_id, Length: 8790, dtype: str

# %%
new_columns_name
# Out:
# ['Show_id',
#  'Type',
#  'Title',
#  'Director',
#  'Country',
#  'Date_added',
#  'Release_year',
#  'Duration',
#  'Listed_in']
