# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.3'

# %%
data=pd.read_csv("FashionDataset.csv")

# %%
data.head
# Out:
# <bound method NDFrame.head of        Unnamed: 0    BrandName  \
# 0               0         life
# 1               1         only
# 2               2      fratini
# 3               3  zink london
# 4               4         life
# ...           ...          ...
# 30753          21    swarovski
# 30754          22          Nan
# 30755          23       jewelz
# 30756          24      estelle
# 30757          25      estelle
#
#                                                  Deatils  \
# 0      solid cotton blend collar neck womens a-line d...
# 1      polyester peter pan collar womens blouson dres...
# 2      solid polyester blend wide neck womens regular...
# 3      stripes polyester sweetheart neck womens dress...
# 4      regular fit regular length denim womens jeans ...
# ...                                                  ...
# 30753            crystal stylish womens rodhium earrings
# 30754                                                Nan
# ...

# %%
data.tail()
# Out:
#        Unnamed: 0  BrandName  \
# 30753          21  swarovski
# 30754          22        Nan
# 30755          23     jewelz
# 30756          24    estelle
# 30757          25    estelle
#
#                                                  Deatils Sizes       MRP  \
# 30753            crystal stylish womens rodhium earrings   Nan       Nan
# 30754                                                Nan   Nan       Nan
# 30755                 ethnic gold plated jhumki earrings   Nan  Rs\n1839
# 30756  womens gold plated double line fancy white and...   Nan       Nan
# 30757  womens gold plated bridge designer mangalsutra...   Nan       Nan
#
#       SellPrice Discount         Category
# 30753      8950      Nan  Jewellery-Women
# 30754       Nan      Nan  Jewellery-Women
# 30755       643  65% off  Jewellery-Women
# 30756      2799      Nan  Jewellery-Women
# 30757      1899      Nan  Jewellery-Women

# %%
"""Deleting redundant columns.
Renaming the columns.
Dropping duplicates.
Remove the NaN values from the dataset
Check for some more Transformations"""

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30758 entries, 0 to 30757
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  30758 non-null  int64
#  1   BrandName   30758 non-null  str
#  2   Deatils     30758 non-null  str
#  3   Sizes       30758 non-null  str
#  4   MRP         30758 non-null  str
#  5   SellPrice   30758 non-null  str
#  6   Discount    30758 non-null  str
#  7   Category    30758 non-null  str
# dtypes: int64(1), str(7)
# memory usage: 1.9 MB

# %%
data.shape
# Out:
# (30758, 8)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'BrandName', 'Deatils', 'Sizes', 'MRP', 'SellPrice',
#        'Discount', 'Category'],
#       dtype='str')

# %%
data = data.drop(columns='Unnamed: 0')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 data = data.drop(columns='Unnamed: 0')
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
data
# Out:
#        Unnamed: 0    BrandName  \
# 0               0         life
# 1               1         only
# 2               2      fratini
# 3               3  zink london
# 4               4         life
# ...           ...          ...
# 30753          21    swarovski
# 30754          22          Nan
# 30755          23       jewelz
# 30756          24      estelle
# 30757          25      estelle
#
#                                                  Deatils  \
# 0      solid cotton blend collar neck womens a-line d...
# 1      polyester peter pan collar womens blouson dres...
# 2      solid polyester blend wide neck womens regular...
# 3      stripes polyester sweetheart neck womens dress...
# 4      regular fit regular length denim womens jeans ...
# ...                                                  ...
# 30753            crystal stylish womens rodhium earrings
# 30754                                                Nan
# 30755                 ethnic gold plated jhumki earrings
# ...

# %%
if data is None:
  data = pd.read_csv("FashionDataset.csv")
data.columns
# Out:
# Index(['Unnamed: 0', 'BrandName', 'Deatils', 'Sizes', 'MRP', 'SellPrice',
#        'Discount', 'Category'],
#       dtype='str')

# %%
data.rename(columns={"Deatils ": "Details"},inplace=True)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'BrandName', 'Deatils', 'Sizes', 'MRP', 'SellPrice',
#        'Discount', 'Category'],
#       dtype='str')

# %%
# !pip install matplotlib

import matplotlib.pyplot as plt

data.duplicated().value_counts().plot(kind="pie")
plt.xlabel("is_duplicated")
plt.ylabel("count")
plt.title("Duplicate rows")
plt.show()

# %%
data.drop_duplicates(inplace= True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data
# Out:
#        Unnamed: 0           BrandName  \
# 0               0                life
# 1               1                only
# 2               2             fratini
# 3               3         zink london
# 4               4                life
# ...           ...                 ...
# 30752          20  shaya by caratlane
# 30753          21           swarovski
# 30755          23              jewelz
# 30756          24             estelle
# 30757          25             estelle
#
#                                                  Deatils  \
# 0      solid cotton blend collar neck womens a-line d...
# 1      polyester peter pan collar womens blouson dres...
# 2      solid polyester blend wide neck womens regular...
# 3      stripes polyester sweetheart neck womens dress...
# 4      regular fit regular length denim womens jeans ...
# ...                                                  ...
# 30752               the wing woman clover charm necklace
# ...

# %%
data.drop(columns='Unnamed: 0', inplace=True)

# %%
data
# Out:
#        Unnamed: 0           BrandName  \
# 0               0                life
# 1               1                only
# 2               2             fratini
# 3               3         zink london
# 4               4                life
# ...           ...                 ...
# 29422          20  shaya by caratlane
# 29423          21           swarovski
# 29424          23              jewelz
# 29425          24             estelle
# 29426          25             estelle
#
#                                                  Deatils  \
# 0      solid cotton blend collar neck womens a-line d...
# 1      polyester peter pan collar womens blouson dres...
# 2      solid polyester blend wide neck womens regular...
# 3      stripes polyester sweetheart neck womens dress...
# 4      regular fit regular length denim womens jeans ...
# ...                                                  ...
# 29422               the wing woman clover charm necklace
# ...

# %%
data.isna().sum()
# Out:
# BrandName    0
# Deatils      0
# Sizes        0
# MRP          0
# SellPrice    0
# Discount     0
# Category     0
# dtype: int64

# %%
data.dropna(inplace= True)

# %%
data.isna().sum
# Out:
# <bound method DataFrame.sum of        BrandName  Deatils  Sizes    MRP  SellPrice  Discount  Category
# 0          False    False  False  False      False     False     False
# 1          False    False  False  False      False     False     False
# 2          False    False  False  False      False     False     False
# 3          False    False  False  False      False     False     False
# 4          False    False  False  False      False     False     False
# ...          ...      ...    ...    ...        ...       ...       ...
# 29422      False    False  False  False      False     False     False
# 29423      False    False  False  False      False     False     False
# 29424      False    False  False  False      False     False     False
# 29425      False    False  False  False      False     False     False
# 29426      False    False  False  False      False     False     False
#
# [29427 rows x 7 columns]>

# %%
data["BrandName"] = data["BrandName"].apply(lambda x :x.capitalize())

# %%
data["BrandName"] = data["BrandName"].apply(lambda x: x.capitalize())
data["Deatils"] = data["Deatils"].apply(lambda x: x.capitalize())

# %%
data

# %%
data
# Out:
#                 BrandName                                            Deatils  \
# 0                    Life  Solid cotton blend collar neck womens a-line d...
# 1                    Only  Polyester peter pan collar womens blouson dres...
# 2                 Fratini  Solid polyester blend wide neck womens regular...
# 3             Zink london  Stripes polyester sweetheart neck womens dress...
# 4                    Life  Regular fit regular length denim womens jeans ...
# ...                   ...                                                ...
# 29422  Shaya by caratlane               The wing woman clover charm necklace
# 29423           Swarovski            Crystal stylish womens rodhium earrings
# 29424              Jewelz                 Ethnic gold plated jhumki earrings
# 29425             Estelle  Womens gold plated double line fancy white and...
# 29426             Estelle  Womens gold plated bridge designer mangalsutra...
#
# ...

# %%
data.isnull().sum()
# Out:
# BrandName    0
# Deatils      0
# Sizes        0
# MRP          0
# SellPrice    0
# Discount     0
# Category     0
# dtype: int64

# %%
type(data["Sizes"][29425])
# Out:
# str

# %%
data["Sizes"] = data["Sizes"].replace("Nan", "NA VALUED")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 data["Sizes"] = data["Sizes"].replace("Nan", "NA VALUED")
#
# File ~/data cleaning/venv/lib/python3.12/site-packages/pandas/core/series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File ~/data cleaning/venv/lib/python3.12/site-packages/pandas/core/series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
# ...

# %%
data
# Out:
# 0        Size:Large,Medium,Small,X-Large,X-Small
# 1                               Size:34,36,38,40
# 2                    Size:Large,X-Large,XX-Large
# 3                Size:Large,Medium,Small,X-Large
# 4                         Size:26,28,30,32,34,36
#                           ...
# 29422                                  NA VALUED
# 29423                                  NA VALUED
# 29424                                  NA VALUED
# 29425                                  NA VALUED
# 29426                                  NA VALUED
# Name: Sizes, Length: 29427, dtype: str

# %%
data[data == "NA VALUED"]
# Out:
# 22       NA VALUED
# 617      NA VALUED
# 909      NA VALUED
# 1149     NA VALUED
# 1150     NA VALUED
#            ...
# 29422    NA VALUED
# 29423    NA VALUED
# 29424    NA VALUED
# 29425    NA VALUED
# 29426    NA VALUED
# Name: Sizes, Length: 6201, dtype: str

# %%
data
# Out:
# 0        Size:Large,Medium,Small,X-Large,X-Small
# 1                               Size:34,36,38,40
# 2                    Size:Large,X-Large,XX-Large
# 3                Size:Large,Medium,Small,X-Large
# 4                         Size:26,28,30,32,34,36
#                           ...
# 29422                                  NA VALUED
# 29423                                  NA VALUED
# 29424                                  NA VALUED
# 29425                                  NA VALUED
# 29426                                  NA VALUED
# Name: Sizes, Length: 29427, dtype: str

# %%
data = pd.read_csv("FashionDataset.csv")
data["Discount"] = data["Discount"].replace("Nan", "No Discount")

# %%
data
# Out:
#        Unnamed: 0    BrandName  \
# 0               0         life
# 1               1         only
# 2               2      fratini
# 3               3  zink london
# 4               4         life
# ...           ...          ...
# 30753          21    swarovski
# 30754          22          Nan
# 30755          23       jewelz
# 30756          24      estelle
# 30757          25      estelle
#
#                                                  Deatils  \
# 0      solid cotton blend collar neck womens a-line d...
# 1      polyester peter pan collar womens blouson dres...
# 2      solid polyester blend wide neck womens regular...
# 3      stripes polyester sweetheart neck womens dress...
# 4      regular fit regular length denim womens jeans ...
# ...                                                  ...
# 30753            crystal stylish womens rodhium earrings
# 30754                                                Nan
# 30755                 ethnic gold plated jhumki earrings
# ...

# %%
data.reset_index().drop(columns="index")
# Out:
#        Unnamed: 0    BrandName  \
# 0               0         life
# 1               1         only
# 2               2      fratini
# 3               3  zink london
# 4               4         life
# ...           ...          ...
# 30753          21    swarovski
# 30754          22          Nan
# 30755          23       jewelz
# 30756          24      estelle
# 30757          25      estelle
#
#                                                  Deatils  \
# 0      solid cotton blend collar neck womens a-line d...
# 1      polyester peter pan collar womens blouson dres...
# 2      solid polyester blend wide neck womens regular...
# 3      stripes polyester sweetheart neck womens dress...
# 4      regular fit regular length denim womens jeans ...
# ...                                                  ...
# 30753            crystal stylish womens rodhium earrings
# 30754                                                Nan
# 30755                 ethnic gold plated jhumki earrings
# ...

# %%
data.to_excel("cleaned_data.xlsx",index =True)

# %%
data.to_csv("cleaned_data.csv", index =True)
